# %%
## Importing neccesary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import seaborn as sns


sns.set_style('whitegrid')
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\\Ai engineering\\udemy Ml\\internship\\datasets\\Unemployment in India.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %% [markdown]
# ### Check whether the dataset consists of null values

# %%
df.isna().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
df[df.isna()]
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 0      NaN   NaN        NaN                               NaN
# 1      NaN   NaN        NaN                               NaN
# 2      NaN   NaN        NaN                               NaN
# 3      NaN   NaN        NaN                               NaN
# 4      NaN   NaN        NaN                               NaN
# ..     ...   ...        ...                               ...
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 0                    NaN                                       NaN  NaN
# 1                    NaN                                       NaN  NaN
# ...

# %%
## Droping the null values and reseting the index

df.dropna(inplace=True)
df.reset_index(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 8 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   index                                     740 non-null    int64
#  1   Region                                    740 non-null    object
#  2    Date                                     740 non-null    object
#  3    Frequency                                740 non-null    object
#  4    Estimated Unemployment Rate (%)          740 non-null    float64
#  5    Estimated Employed                       740 non-null    float64
#  6    Estimated Labour Participation Rate (%)  740 non-null    float64
#  7   Area                                      740 non-null    object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 46.4+ KB

# %%
df.head()
# Out:
#    index          Region         Date  Frequency  \
# 0      0  Andhra Pradesh   31-05-2019    Monthly
# 1      1  Andhra Pradesh   30-06-2019    Monthly
# 2      2  Andhra Pradesh   31-07-2019    Monthly
# 3      3  Andhra Pradesh   31-08-2019    Monthly
# 4      4  Andhra Pradesh   30-09-2019    Monthly
#
#     Estimated Unemployment Rate (%)   Estimated Employed  \
# 0                              3.65           11999139.0
# 1                              3.05           11755881.0
# 2                              3.75           12086707.0
# 3                              3.32           12285693.0
# 4                              5.17           12256762.0
#
#     Estimated Labour Participation Rate (%)   Area
# 0                                     43.24  Rural
# 1                                     42.05  Rural
# 2                                     43.50  Rural
# 3                                     43.97  Rural
# 4                                     44.68  Rural

# %%
df.tail()
# Out:
#      index       Region         Date  Frequency  \
# 735    749  West Bengal   29-02-2020    Monthly
# 736    750  West Bengal   31-03-2020    Monthly
# 737    751  West Bengal   30-04-2020    Monthly
# 738    752  West Bengal   31-05-2020    Monthly
# 739    753  West Bengal   30-06-2020    Monthly
#
#       Estimated Unemployment Rate (%)   Estimated Employed  \
# 735                              7.55           10871168.0
# 736                              6.67           10806105.0
# 737                             15.63            9299466.0
# 738                             15.22            9240903.0
# 739                              9.86            9088931.0
#
#       Estimated Labour Participation Rate (%)   Area
# 735                                     44.09  Urban
# 736                                     43.34  Urban
# 737                                     41.20  Urban
# 738                                     40.67  Urban
# ...

# %%
df.drop(['index'],axis=1,inplace=True)  ## Droping unwanted columns

# %%
df.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 735  West Bengal   29-02-2020    Monthly                              7.55
# 736  West Bengal   31-03-2020    Monthly                              6.67
# 737  West Bengal   30-04-2020    Monthly                             15.63
# 738  West Bengal   31-05-2020    Monthly                             15.22
# 739  West Bengal   30-06-2020    Monthly                              9.86
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 735           10871168.0                                     44.09  Urban
# 736           10806105.0                                     43.34  Urban
# 737            9299466.0                                     41.20  Urban
# 738            9240903.0                                     40.67  Urban
# 739            9088931.0                                     37.57  Urban

# %% [markdown]
# ### Performing EDA:

# %%
df.columns=df.columns.str.strip() ## removing extra spaces from column names

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
### We will calculate Estimated Unemployment Rate (%) by Region


a=pd.DataFrame(df.groupby('Region')['Estimated Unemployment Rate (%)'].agg('sum').reset_index())

# %%
a
# Out:
#               Region  Estimated Unemployment Rate (%)
# 0     Andhra Pradesh                           209.36
# 1              Assam                           167.13
# 2              Bihar                           529.71
# 3         Chandigarh                           191.90
# 4       Chhattisgarh                           258.73
# 5              Delhi                           461.87
# 6                Goa                           222.58
# 7            Gujarat                           186.59
# 8            Haryana                           735.93
# 9   Himachal Pradesh                           519.13
# 10   Jammu & Kashmir                           339.96
# 11         Jharkhand                           576.38
# 12         Karnataka                           186.93
# 13            Kerala                           283.47
# 14    Madhya Pradesh                           207.38
# 15       Maharashtra                           211.61
# ...

# %%
## Now we will plot graph b/w Estimated Unemployment Rate (%) and Region

plt.figure(figsize=(20,6))
plt.plot(a['Region'],a['Estimated Unemployment Rate (%)'],marker='o')
plt.xlabel('Regions')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate vs Region')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Sikkim has Less Unemployment Rate and Tripura has high

# %%
len(a['Region'])
# Out:
# 28

# %%
z=[0.1 for _ in range(len(a['Estimated Unemployment Rate (%)']))]

# %%
### We will plot a pie chart also
plt.figure(figsize=(10,10))
plt.pie(a['Estimated Unemployment Rate (%)'],labels=a['Region'],autopct='%1.1f%%',explode=z)
plt.title('Unemployment Share per Region',color='r',loc='center')
plt.style.use('ggplot')
plt.show()

# %%
df.tail()
# Out:
#           Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 735  West Bengal   29-02-2020   Monthly                             7.55
# 736  West Bengal   31-03-2020   Monthly                             6.67
# 737  West Bengal   30-04-2020   Monthly                            15.63
# 738  West Bengal   31-05-2020   Monthly                            15.22
# 739  West Bengal   30-06-2020   Monthly                             9.86
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 735          10871168.0                                    44.09  Urban
# 736          10806105.0                                    43.34  Urban
# 737           9299466.0                                    41.20  Urban
# 738           9240903.0                                    40.67  Urban
# 739           9088931.0                                    37.57  Urban

# %%
## Now we will perform same thing for Estimated Labour Participation Rate (%)


a=pd.DataFrame(df.groupby('Region')['Estimated Labour Participation Rate (%)'].agg('sum').reset_index())

# %%
## Now we will plot graph b/w Estimated Labour Participation Rate (%) and Region

plt.figure(figsize=(20,6))
plt.plot(a['Region'],a['Estimated Labour Participation Rate (%)'],marker='o')
plt.xlabel('Regions')
plt.ylabel('employment Rate')
plt.title('employment Rate vs Region')
plt.xticks(rotation=75)
plt.show()

# %%
### We will plot a pie chart also
plt.figure(figsize=(10,10))
plt.pie(a['Estimated Labour Participation Rate (%)'],labels=a['Region'],autopct='%1.1f%%')
plt.title('employment Share per Region',color='r',loc='center')
plt.style.use('ggplot')
plt.show()

# %%
df.tail()
# Out:
#           Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 735  West Bengal   29-02-2020   Monthly                             7.55
# 736  West Bengal   31-03-2020   Monthly                             6.67
# 737  West Bengal   30-04-2020   Monthly                            15.63
# 738  West Bengal   31-05-2020   Monthly                            15.22
# 739  West Bengal   30-06-2020   Monthly                             9.86
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 735          10871168.0                                    44.09  Urban
# 736          10806105.0                                    43.34  Urban
# 737           9299466.0                                    41.20  Urban
# 738           9240903.0                                    40.67  Urban
# 739           9088931.0                                    37.57  Urban

# %%
df['Frequency']=df['Frequency'].str.strip() ## Adjusting the Values

# %%
df['Frequency'].value_counts()
# Out:
# Frequency
# Monthly    740
# Name: count, dtype: int64

# %%
df['Area'].value_counts()
# Out:
# Area
# Urban    381
# Rural    359
# Name: count, dtype: int64

# %%
### Now We will see Estimated Labour Participation Rate (%) based on Urban and Rural

a=pd.DataFrame(df.groupby(['Area'])['Estimated Labour Participation Rate (%)'].agg('mean').reset_index())

# %%
## We will Visualize this

import seaborn as sns
plt.figure(figsize=(20,5))
plt.bar(a['Area'],height=a['Estimated Labour Participation Rate (%)'],width=0.1,)
plt.xlabel('Area')
plt.ylabel('Estimated Labour Participation Rate (%)')
plt.title('Area VS Estimated Labour Participation Rate (%)')
plt.show()

# %%
sns.kdeplot(a['Estimated Labour Participation Rate (%)'],color='b',fill=True,palette='hsl')
# Out:
# <Axes: xlabel='Estimated Labour Participation Rate (%)', ylabel='Density'>

# %% [markdown]
# ### It follows Normal/Guassian Distribution

# %%
## Ploting all Possible plots
sns.pairplot(df,palette='hsl',height=5.0)

# %%
df.tail()
# Out:
#           Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 735  West Bengal   29-02-2020   Monthly                             7.55
# 736  West Bengal   31-03-2020   Monthly                             6.67
# 737  West Bengal   30-04-2020   Monthly                            15.63
# 738  West Bengal   31-05-2020   Monthly                            15.22
# 739  West Bengal   30-06-2020   Monthly                             9.86
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 735          10871168.0                                    44.09  Urban
# 736          10806105.0                                    43.34  Urban
# 737           9299466.0                                    41.20  Urban
# 738           9240903.0                                    40.67  Urban
# 739           9088931.0                                    37.57  Urban

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    object
#  2   Frequency                                740 non-null    object
#  3   Estimated Unemployment Rate (%)          740 non-null    float64
#  4   Estimated Employed                       740 non-null    float64
#  5   Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                     740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 40.6+ KB

# %%
## The Date should be in DateTime format we will convert it into that


df['Date']=pd.to_datetime(df['Date'])

# %%
df
# Out:
#              Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1    Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2    Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3    Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4    Andhra Pradesh 2019-09-30   Monthly                             5.17
# ..              ...        ...       ...                              ...
# 735     West Bengal 2020-02-29   Monthly                             7.55
# 736     West Bengal 2020-03-31   Monthly                             6.67
# 737     West Bengal 2020-04-30   Monthly                            15.63
# 738     West Bengal 2020-05-31   Monthly                            15.22
# 739     West Bengal 2020-06-30   Monthly                             9.86
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# ...

# %%
### Estimated Unemployment Rate (%)	 VS Estimated Labour Participation Rate (%)	
plt.figure(figsize=(20,5))
sns.distplot(df['Estimated Unemployment Rate (%)'],kde=True)
sns.distplot(df['Estimated Labour Participation Rate (%)'],kde=True)
# Out:
# <Axes: xlabel='Estimated Labour Participation Rate (%)', ylabel='Density'>

# %%
df.to_csv("Unemployment in India.csv")
